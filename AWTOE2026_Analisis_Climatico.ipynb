# %% [markdown]
# <a href="https://colab.research.google.com/github/dogliolinico/weather-app-utn-jira/blob/main/AWTOE2026_Analisis_Climatico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Entrar a la carpeta usando el nombre exacto de tu repositorio clonado
# %cd weather-app-utn-jira/scripts

# 2. Ejecutar el script de análisis climático de Belfast
# !python analisis_datos.py
# Out:
# /content/weather-app-utn-jira/scripts
# ¡Procesamiento completo! El gráfico y los indicadores se guardaron en /resultados
